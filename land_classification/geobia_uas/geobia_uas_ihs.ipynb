# %% [markdown]
# # Introduction
#
# This notebook will go through the steps to undertake a classification using a segmentation rather than a pixel based classification.
#
# A number of studies have proposed that segmenting an image and classifying the segments can produce a better classification result than classifying individual pixels.
#
# The notebook will go through the following steps:
#
# Perform segmentation
# Populate segments with data
# Extract sample data
# Split sample data into training, testing and validation sets
# Training Classifier
# Apply Classifier
# Running Notebook
# The notebook has been run and saved with the outputs so you can see what the outputs should be and so the notebook and be browsed online without having to run the notebook for it to make sense.
#
# If you are running the notebook for yourself it is recommended that you clear the existing outputs which can be done by running one of the following options depending on what system you are using:
#
# ### Jupyter-lab:
#
# > Edit > 'Clear All Outputs'
#
# ### Jupyter-notebook:
#
# > Cell > 'All Outputs' > Clear

# %% [markdown]
# ### Fuente:
#
# Código adaptado de RSGISLib Tutorials
# Repositorio: https://github.com/remotesensinginfo/rsgislib-tutorials
# Segmentación: https://github.com/remotesensinginfo/rsgislib-tutorials/blob/main/03_intro_image_classification/02_segment_ml_classification.ipynb

# %%
# Import modules from python standard library
import os
import pprint
import random

# Import the matplotlib plotting module and set it to work within
# a notebook environment.

import matplotlib
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt

# Import the RSGISLib modules for the notebook
import rsgislib
import rsgislib.classification
import rsgislib.classification.classratutils
import rsgislib.classification.classsklearn
import rsgislib.rastergis
import rsgislib.tools.filetools
import rsgislib.tools.mapping
import rsgislib.vectorutils
import rsgislib.vectorutils.createrasters
import rsgislib.zonalstats
from rsgislib.segmentation import shepherdseg
from sklearn.ensemble import RandomForestClassifier

# Import the geopandas module
os.environ["USE_PYGEOS"] = "0"
import geopandas

# Import the numpy module
import numpy

# scikit-learn imports
from sklearn.model_selection import GridSearchCV

# %%
input_img = "/Users/felipehernandez/Documents/Natalia/Desarrollo/Repos/data/fusion_satelite_uav/processed_images/uas_05m/ihs/RGB832/IHS_2022_10_RGB832_uas_05m.tif"

# Create a plot using the matplotlib library
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the image data using bands 8, 9, 3 (NIR, SWIR1, Red)
# which produces a good false colour visualisation which is
# good at picking out vegetation. If you want a true colour
# (i.e., Red, Green, Blue) visualisation change the bands to
# [3, 2, 1]

rsgislib.tools.mapping.create_raster_img_map(ax, 
                                             input_img, 
                                             img_bands=[3, 2, 1], 
                                             img_stch=rsgislib.IMG_STRETCH_STDEV)
# Out:
# Image Data Size: 2105 x 2403

# %%
out_clumps_img = "IHS_2022_10_RGB832_uas_05m_segs.kea"
out_mean_img = "IHS_2022_10_RGB832_uas_05m_meanimg.kea"
tmp_dir = "tmp"

shepherdseg.run_shepherd_segmentation(
    input_img,
    out_clumps_img,
    out_mean_img,
    tmp_dir,
    gdalformat="KEA",  # Output file format
    calc_stats=True,  # Calculate statistics on the output images
    no_stretch=False,  # Normalise the input bands by applying a 2 standard devation stretch
    no_delete=False,  # Delete the temporary files created during the processing
    num_clusters=60,  # The number of clusters (k) for the initial kMeans clustering
    min_n_pxls=100,  # Minimum number of pixels within a clump (segment)
    dist_thres=100,
    bands=[3, 2, 1],  # Just use bands 8 (NIR), 9 (SWIR) and 3 (Red)
    sampling=100,  # Speed up the kMeans clustering by only using every 100th pixel.
    km_max_iter=200,  # Maximum number of kMeans iterations
    process_in_mem=True,  # Do the process using in-memory datasets rather than to disk
    save_process_stats=False,
    img_stretch_stats="",
    kmeans_centres="",
    img_stats_json_file="",
)
# Out:
# Subsetting the image bands
# New image width = 2105 height = 2403 bands = 3
#
# Stretch Input Image
# Add 1 to stretched file to ensure there are no all zeros (i.e., no data) regions created.
#
#
# Band[1] Min = 0 Mean = 27.1522102939 (Std Dev = 23.7412120594) max = 255
# Band[2] Min = 3 Mean = 29.7875782746 (Std Dev = 13.0958168038) max = 71
# Band[3] Min = 10 Mean = 41.6532410496 (Std Dev = 24.1360293486) max = 118
# New image width = 2105 height = 2403 bands = 3
#
# New image width = 2105 height = 2403 bands = 3
#
# Create Input Image Mask.
# Image: tmp/IHS_2022_10_RGB832_uas_05m_bselect.kea
# 	 Variable 'b1' is band 1
# New image width = 2105 height = 2403 bands = 1
#
# Mask stretched Image.
# New image width = 2105 height = 2403 bands = 3
#
# Deleting file: tmp/IHS_2022_10_RGB832_uas_05m_stchdonly.kea
# Deleting file: tmp/IHS_2022_10_RGB832_uas_05m_stchdonly_off.kea
# Deleting file: tmp/IHS_2022_10_RGB832_uas_05m_stchdmaskonly.kea
# Performing KMeans.
# Apply KMeans to image.
# inputImage = tmp/IHS_2022_10_RGB832_uas_05m_stchd.kea
# outputMatrixFile = tmp/IHS_2022_10_RGB832_uas_05m_kmeansclusters
# numClusters = 60
# maxNumIterations = 200
# subSample = 100
# degreeOfChange = 0.00249999994412
# Eliminate Single Pixels.
# Perform clump.
# Eliminate small pixels.
# Ignoring Zeros
# Full diag attached.
# Subsampling the image to read into memory
# Performing clustering
# Starting Iterative processing...
# Iteration 0 has change 22.6260700226 % of data clump IDs (60 clusters).
# Iteration 1 has change 37.7961807251 % of data clump IDs (59 clusters).
# Iteration 2 has change 6.10538434982 % of data clump IDs (59 clusters).
# Iteration 3 has change 4.58003139496 % of data clump IDs (59 clusters).
# Iteration 4 has change 3.64257478714 % of data clump IDs (59 clusters).
# Iteration 5 has change 3.50155901909 % of data clump IDs (59 clusters).
# Iteration 6 has change 3.12022089958 % of data clump IDs (59 clusters).
# Iteration 7 has change 2.94941306114 % of data clump IDs (59 clusters).
# Iteration 8 has change 2.9235932827 % of data clump IDs (59 clusters).
# Iteration 9 has change 2.60382533073 % of data clump IDs (59 clusters).
# Iteration 10 has change 2.60183930397 % of data clump IDs (59 clusters).
# Iteration 11 has change 2.00798416138 % of data clump IDs (59 clusters).
# IteRelabel clumps.
# ration 12 has change 1.70807766914 % of data clump IDs (59 clusters).
# Iteration 13 has change 2.2165286541 % of data clump IDs (59 clusters).
# Iteration 14 has change 1.81532895565 % of data clump IDs (59 clusters).
# Iteration 15 has change 1.55117273331 % of data clump IDs (59 clusters).
# Iteration 16 has change 1.41810166836 % of data clump IDs (59 clusters).
# Iteration 17 has change 1.63657665253 % of data clump IDs (59 clusters).
# Iteration 18 has change 1.26119685173 % of data clump IDs (59 clusters).
# Iteration 19 has change 0.989096164703 % of data clump IDs (59 clusters).
# Iteration 20 has change 0.963276326656 % of data clump IDs (59 clusters).
# Iteration 21 has change 0.820274472237 % of data clump IDs (59 clusters).
# Iteration 22 has change 0.641522169113 % of data clump IDs (59 clusters).
# Iteration 23 has change 0.895747661591 % of data clump IDs (59 clusters).
# Iteration 24 has change 0.591868758202 % of data clump IDs (59 clusters).
# Iteration 25 has change 0.820274472237 % of data clump IDs (59 clusters).
# Iteration 26 has change 0.597827196121 % of data clump IDs (59 clusters).
# Iteration 27 has change 0.637549877167 % of data clump IDs (59 clusters).
# Iteration 28 has change 0.301892787218 % of data clump IDs (59 clusters).
# Iteration 29 has change 0.484617382288 % of data clump IDs (59 clusters).
# Iteration 30 has change 0.44489467144 % of data clump IDs (59 clusters).
# Iteration 31 has change 0.62166082859 % of data clump IDs (59 clusters).
# Iteration 32 has change 0.740828990936 % of data clump IDs (59 clusters).
# Iteration 33 has change 0.530298531055 % of data clump IDs (59 clusters).
# Iteration 34 has change 0.508450984955 % of data clump IDs (59 clusters).
# Iteration 35 has change 0.468728274107 % of data clump IDs (59 clusters).
# Iteration 36 has change 0.508450984955 % of data clump IDs (59 clusters).
# Iteration 37 has change 0.556118249893 % of data clump IDs (59 clusters).
# Iteration 38 has change 0.552146017551 % of data clump IDs (59 clusters).
# Iteration 39 haCalculate image statistics and build pyramids.
# s change 0.468728274107 % of data clump IDs (59 clusters).
# Iteration 40 has change 0.399213463068 % of data clump IDs (59 clusters).
# Iteration 41 has change 0.206558227539 % of data clump IDs (59 clusters).
# Exporting cluster centres to output file
# New image width = 2105 height = 2403 bands = 1
#
# Eliminating Individual Pixels
#
# There are 379899 single pixels within the image
#
#
# There are 7546 single pixels within the image
#
#
# There are 224 single pixels within the image
#
#
# There are 152 single pixels within the image
#
#
# There are 146 single pixels within the image
#
# Complete, all connected single pixels have been removed
# Processing in Memory
# Performing Clump
#
#
# (Generated 208776 clumps).
# Copying output to disk
# Processing in Memory
# Eliminant Clumps
# Calc Number of clumps
#
# Build clump table
# Calculate Initial Clump Means
# There are 208776 clumps.
# Eliminating Small Clumps.
# Eliminating clumps of size 1
# Found 146 small clumps to be eliminated.
# Eliminated 146 small clumps
# Eliminating clumps of size 2
# Found 47389 small clumps to be eliminated.
# Eliminated 47535 small clumps
# Eliminating clumps of size 3
# Found 34003 small clumps to be eliminated.
# Eliminated 81538 small clumps
# Eliminating clumps of size 4
# Found 23503 small clumps to be eliminated.
# Eliminated 105041 small clumps
# Eliminating clumps of size 5
# Found 17722 small clumps to be eliminated.
# Eliminated 122763 small clumps
# Eliminating clumps of size 6
# Found 12211 small clumps to be eliminated.
# Eliminated 134974 small clumps
# Eliminating clumps of size 7
# Found 10750 small clumps to be eliminated.
# Eliminated 145724 small clumps
# Eliminating clumps of size 8
# Found 8598 small clumps to be eliminated.
# Eliminated 154322 small clumps
# Eliminating clumps of size 9
# Found 7911 small clumps to be eliminated.
# Eliminated 162233 small clumps
# Eliminating clumps of size 10
# Found 6501 small clumps to be eliminated.
# Eliminated 168734 small clumps
# Eliminating clumps of size 11
# Found 6336 small clumps to be eliminated.
# Eliminated 175070 small clumps
# Eliminating clumps of size 12
# Found 5819 small clumps to be eliminated.
# Eliminated 180889 small clumps
# Eliminating clumps of size 13
# Found 5355 small clumps to be eliminated.
# Eliminated 186244 small clumps
# Eliminating clumps of size 14
# Found 5055 small clumps to be eliminated.
# Eliminated 191299 small clumps
# Eliminating clumps of size 15
# Found 4902 small clumps to be eliminated.
# Eliminated 196201 small clumps
# Eliminating clumps of size 16
# Found 4555 small clumps to be eliminated.
# Eliminated 200756 small clumps
# Eliminating clumps of size 17
# Found 4493 small clumps to be eliminated.
# Eliminated 205249 small clumps
# Eliminating clumps of size 18
# Found 4194 small clumps to be eliminated.
# Eliminated 209443 small clumps
# Eliminating clumps of size 19
# Found 4228 small clumps to be eliminated.
# Eliminated 213671 small clumps
# Eliminating clumps of size 20
# Found 4013 small clumps to be eliminated.
# Eliminated 217684 small clumps
# Eliminating clumps of size 21
# Found 3937 small clumps to be eliminated.
# EliminDeleting file: tmp/IHS_2022_10_RGB832_uas_05m_kmeansclusters.gmtxt
# ated 221621 small clumps
# Eliminating clumps of size 22
# Found 3838 small clumps to be eliminated.
# Eliminated 225459 small clumps
# Eliminating clumps of size 23
# Found 3817 small clumps to be eliminated.
# Eliminated 229276 small clumps
# Eliminating clumps of size 24
# Found 3707 small clumps to be eliminated.
# Eliminated 232983 small clumps
# Eliminating clumps of size 25
# Found 3636 small clumps to be eliminated.
# Eliminated 236619 small clumps
# Eliminating clumps of size 26
# Found 3539 small clumps to be eliminated.
# Eliminated 240158 small clumps
# Eliminating clumps of size 27
# Found 3558 small clumps to be eliminated.
# Eliminated 243716 small clumps
# Eliminating clumps of size 28
# Found 3499 small clumps to be eliminated.
# Eliminated 247215 small clumps
# Eliminating clumps of size 29
# Found 3499 small clumps to be eliminated.
# Eliminated 250714 small clumps
# Eliminating clumps of size 30
# Found 3441 small clumps to be eliminated.
# Eliminated 254155 small clumps
# Eliminating clumps of size 31
# Found 3386 small clumps to be eliminated.
# Eliminated 257541 small clumps
# Eliminating clumps of size 32
# Found 3357 small clumps to be eliminated.
# Eliminated 260898 small clumps
# Eliminating clumps of size 33
# Found 3313 small clumps to be eliminated.
# Eliminated 264211 small clumps
# Eliminating clumps of size 34
# Found 3272 small clumps to be eliminated.
# Eliminated 267483 small clumps
# Eliminating clumps of size 35
# Found 3286 small clumps to be eliminated.
# Eliminated 270769 small clumps
# Eliminating clumps of size 36
# Found 3252 small clumps to be eliminated.
# Eliminated 274021 small clumps
# Eliminating clumps of size 37
# Found 3268 small clumps to be eliminated.
# Eliminated 277289 small clumps
# Eliminating clumps of size 38
# Found 3227 small clumps to be eliminated.
# Eliminated 280516 small clumps
# Eliminating clumps of size 39
# Found 3200 small clumps to be eliminated.
# Eliminated 283716 small clumps
# Eliminating clumps of size 40
# Found 3212 small clumps to be eliminated.
# Eliminated 286928 small clumps
# Eliminating clumps of size 41
# Found 3209 small clumps to be eliminated.
# Eliminated 290137 small clumps
# Eliminating clumps of size 42
# Found 3103 small clumps to be eliminated.
# Eliminated 293240 small clumps
# Eliminating clumps of size 43
# Found 3129 small clumps to be eliminated.
# Eliminated 296369 small clumps
# Eliminating clumps of size 44
# Found 3151 small clumps to be eliminated.
# Eliminated 299520 small clumps
# Eliminating clumps of size 45
# Found 3136 small clumps to be eliminated.
# Eliminated 302656 small clumps
# Eliminating clumps of size 46
# Found 3113 small clumps to be eliminated.
# Eliminated 305769 small clumps
# Eliminating clumps of size 47
# Found 3120 small clumps to be eliminated.
# Eliminated 308889 small clumps
# Eliminating clumps of size 48
# Found 3119 small clumps to be eliminated.
# Eliminated 312008 small clumps
# Eliminating clumps of size 49
# Found 3104 small clumps to be eliminated.
# Eliminated 315112 small clumps
# Eliminating clumps of size 50
# Found 3107 small clumps to be eliminated.
# Eliminated 318219 small clumps
# Eliminating clumps of size 51
# Found 3130 small clumps to be eliminated.
# Eliminated 321349 small clumps
# Eliminating clumps of size 52
# Found 3096 small clumps to be eliminated.
# Eliminated 324445 small clumps
# Eliminating clumps of size 53
# Found 3095 small clumps to be eliminated.
# Eliminated 327540 small clumps
# Eliminating clumps of size 54
# Found 3085 small clumps to be eliminated.
# Eliminated 330625 small clumps
# Eliminating clumps of size 55
# Found 3091 small clumps to be eliminated.
# Eliminated 333716 small clumps
# Eliminating clumps of size 56
# Found 3103 small clumps to be eliminated.
# Eliminated 336819 small clumps
# Eliminating clumps of size 57
# Found 3099 small clumps to be eliminated.
# Eliminated 339918 small clumps
# Eliminating clumps of size 58
# Found 3070 small clumps to be eliminated.
# Eliminated 342988 small clumps
# Eliminating clumps of size 59
# Found 3053 small clumps to be eliminated.
# Eliminated 346041 small clumps
# Eliminating clumps of size 60
# Found 3075 small clumps to be eliminated.
# Eliminated 349116 small clumps
# Eliminating clumps of size 61
# Found 3073 small clumps to be eliminated.
# Eliminated 352189 small clumps
# Eliminating clumps of size 62
# Found 3090 small clumps to be eliminated.
# Eliminated 355279 small clumps
# Eliminating clumps of size 63
# Found 3073 small clumps to be eliminated.
# Eliminated 358352 small clumps
# Eliminating clumps of size 64
# Found 3070 small clumps to be eliminated.
# Eliminated 361422 small clumps
# Eliminating clumps of size 65
# Found 3080 small clumps to be eliminated.
# Eliminated 364502 small clumps
# Eliminating clumps of size 66
# Found 3052 small clumps to be eliminated.
# Eliminated 367554 small clumps
# Eliminating clumps of size 67
# Found 3048 small clumps to be eliminated.
# Eliminated 370602 small clumps
# Eliminating clumps of size 68
# Found 3071 small clumps to be eliminated.
# Eliminated 373673 small clumps
# Eliminating clumps of size 69
# Found 3065 small clumps to be eliminated.
# Eliminated 376738 small clumps
# Eliminating clumps of size 70
# Found 3050 small clumps to be eliminated.
# Eliminated 379788 small clumps
# Eliminating clumps of size 71
# Found 3047 small clumps to be eliminated.
# Eliminated 382835 small clumps
# Eliminating clumps of size 72
# Found 3043 small clumps to be eliminated.
# Eliminated 385878 small clumps
# Eliminating clumps of size 73
# Found 3036 small clumps to be eliminated.
# Eliminated 388914 small clumps
# Eliminating clumps of size 74
# Found 3039 small clumps to be eliminated.
# Eliminated 391953 small clumps
# Eliminating clumps of size 75
# Found 3045 small clumps to be eliminated.
# Eliminated 394998 small clumps
# Eliminating clumps of size 76
# Found 3030 small clumps to be eliminated.
# Eliminated 398028 small clumps
# Eliminating clumps of size 77
# Found 3027 small clumps to be eliminated.
# Eliminated 401055 small clumps
# Eliminating clumps of size 78
# Found 2995 small clumps to be eliminated.
# Eliminated 404050 small clumps
# Eliminating clumps of size 79
# Found 3015 small clumps to be eliminated.
# Eliminated 407065 small clumps
# Eliminating clumps of size 80
# Found 3010 small clumps to be eliminated.
# Eliminated 410075 small clumps
# Eliminating clumps of size 81
# Found 3028 small clumps to be eliminated.
# Eliminated 413103 small clumps
# Eliminating clumps of size 82
# Found 3014 small clumps to be eliminated.
# Eliminated 416117 small clumps
# Eliminating clumps of size 83
# Found 3033 small clumps to be eliminated.
# Eliminated 419150 small clumps
# Eliminating clumps of size 84
# Found 3009 small clumps to be eliminated.
# Eliminated 422159 small clumps
# Eliminating clumps of size 85
# Found 3020 small clumps to be eliminated.
# Eliminated 425179 small clumps
# Eliminating clumps of size 86
# Found 3000 small clumps to be eliminated.
# Eliminated 428179 small clumps
# Eliminating clumps of size 87
# Found 3020 small clumps to be eliminated.
# Eliminated 431199 small clumps
# Eliminating clumps of size 88
# Found 3005 small clumps to be eliminated.
# Eliminated 434204 small clumps
# Eliminating clumps of size 89
# Found 3016 small clumps to be eliminated.
# Eliminated 437220 small clumps
# Eliminating clumps of size 90
# Found 3003 small clumps to be eliminated.
# Eliminated 440223 small clumps
# Eliminating clumps of size 91
# Found 3018 small clumps to be eliminated.
# Eliminated 443241 small clumps
# Eliminating clumps of size 92
# Found 3031 small clumps to be eliminated.
# Eliminated 446272 small clumps
# Eliminating clumps of size 93
# Found 3024 small clumps to be eliminated.
# Eliminated 449296 small clumps
# Eliminating clumps of size 94
# Found 3021 small clumps to be eliminated.
# Eliminated 452317 small clumps
# Eliminating clumps of size 95
# Found 2998 small clumps to be eliminated.
# Eliminated 455315 small clumps
# Eliminating clumps of size 96
# Found 3008 small clumps to be eliminated.
# Eliminated 458323 small clumps
# Eliminating clumps of size 97
# Found 3033 small clumps to be eliminated.
# Eliminated 461356 small clumps
# Eliminating clumps of size 98
# Found 2995 small clumps to be eliminated.
# Eliminated 464351 small clumps
# Eliminating clumps of size 99
# Found 3008 smaDeleting file: tmp/IHS_2022_10_RGB832_uas_05m_kmeans.kea
# ll clumps to be eliminated.
# Eliminated 467359 small clumps
# Eliminating clumps of size 100
# Found 3022 small clumps to be eliminated.
# Eliminated 470381 small clumps
# Finshed Elimination. 470381 small clumps eliminated
# Copying output to disk
# Opening clumps file: tmp/IHS_2022_10_RGB832_uas_05m_clumps_elim.kea
# Processing in Memory
# Performing relabel
# Finding maximum image value
#
# Creating Look up table.
#
# Applying Look up table.
#
# Copying output to disk
# Get Image Min and Max.
#
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
# Processing using Disk
# Calculating Mean Image
# Finding maximum image value
#
# Build clump table
# Creating Look up table.
#
# Applying Look up table.
#
#
#
# Calculating Image Pyramids.
#
#
#
# Deleting file: tmp/IHS_2022_10_RGB832_uas_05m_kmeans.kea.aux.xml
# Deleting file: tmp/IHS_2022_10_RGB832_uas_05m_kmeans_nosgl.kea
# Deleting file: tmp/IHS_2022_10_RGB832_uas_05m_clumps.kea
# Deleting file: tmp/IHS_2022_10_RGB832_uas_05m_clumps_elim.kea
# Deleting file: tmp/IHS_2022_10_RGB832_uas_05m_bselect.kea
# Deleting file: tmp/IHS_2022_10_RGB832_uas_05m_stchd.kea

# %%
import rsgislib.vectorutils.createvectors

segs_vec_file = "IHS_2022_10_RGB832_uas_05m_segs.gpkg"
segs_vec_lyr = "IHS_2022_10_RGB832_uas_05m_segs"

rsgislib.vectorutils.createvectors.polygonise_raster_to_vec_lyr(
    out_vec_file=segs_vec_file,  # The output vector file name and path
    out_vec_lyr=segs_vec_lyr,  # The output vector layer name
    out_format="GPKG",  # The output vector format
    input_img=out_clumps_img,  # The input segmentation image
    img_band=1,  # The band within the input image
    mask_img=out_clumps_img,  # A mask image (usually the same as the input image)
    mask_band=1,  # The band within the mask image
)
# Out:
#   6%|██▌                                        | 6/100 [00:00<00:01, 53.46it/s]
# Polygonising...
# 101it [00:07, 14.18it/s]
# Completed

# %%
bs = []
bs.append(rsgislib.rastergis.BandAttStats(band=1, mean_field="blue_refl"))
bs.append(rsgislib.rastergis.BandAttStats(band=2, mean_field="green_refl"))
bs.append(rsgislib.rastergis.BandAttStats(band=3, mean_field="nir_b8_refl"))
rsgislib.rastergis.populate_rat_with_stats(input_img, out_clumps_img, bs)

# %%
# Create Training Rasterise tmp directory
tmp_train_dir = "train_tmp"
if not os.path.exists(tmp_train_dir):
    os.mkdir(tmp_train_dir)

vec_train_file = "/Users/felipehernandez/Documents/entrenamiento.gpkg"

# Define Training Data
class_vec_sample_clumps_info = list()

# Define the file name of the samples HDF5 file, which will be created
pastos_limpios_clumps_h5 = "pastos_limpios_smpls_clumps.h5"
class_vec_sample_clumps_info.append(
    rsgislib.classification.ClassVecSamplesInfoObj(
        id=1,
        class_name="pastos_limpios",
        vec_file=vec_train_file,
        vec_lyr="pastos_limpios",
        file_h5=pastos_limpios_clumps_h5,
    )
)

# Define the file name of the samples HDF5 file, which will be created
pastos_espacios_naturales_clumps_h5 = "pastos_espacios_naturales_smpls_clumps.h5"
class_vec_sample_clumps_info.append(
    rsgislib.classification.ClassVecSamplesInfoObj(
        id=2,
        class_name="pastos_espacios_naturales",
        vec_file=vec_train_file,
        vec_lyr="pastos_espacios_naturales",
        file_h5=pastos_espacios_naturales_clumps_h5,
    )
)


# Define the file name of the samples HDF5 file, which will be created
lagunas_lagos_cienagas_naturales_clumps_h5 = "lagunas_lagos_cienagas_naturales_clumps.h5"
class_vec_sample_clumps_info.append(
    rsgislib.classification.ClassVecSamplesInfoObj(
        id=3,
        class_name="lagunas_lagos_cienagas_naturales",
        vec_file=vec_train_file,
        vec_lyr="lagunas_lagos_cienagas_naturales",
        file_h5=lagunas_lagos_cienagas_naturales_clumps_h5,
    )
)

# Define the file name of the samples HDF5 file, which will be created
arbustal_clumps_h5 = "arbustal_smpls_clumps.h5"
class_vec_sample_clumps_info.append(
    rsgislib.classification.ClassVecSamplesInfoObj(
        id=4,
        class_name="arbustal",
        vec_file=vec_train_file,
        vec_lyr="arbustal",
        file_h5=arbustal_clumps_h5,
    )
)

rsgislib.classification.classratutils.populate_clumps_with_class_training(
    out_clumps_img,
    class_vec_sample_clumps_info,
    tmp_train_dir,
    classes_int_col="class_int_smpls",
    classes_name_col="class_name_smpls",
)
# Out:
# Creating output image using input image
# Running Rasterise now...
# Writing Stats (Mean, ) to Output RAT
#
# Get Image Min and Max.
#
# Creating output image using input image
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
#
# Running Rasterise now...
# Get Image Min and Max.
#
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
# Creating output image using input image
#
# Running Rasterise now...
# Get Image Min and Max.
#
# Creating output image using input image
# Running Rasterise now...
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
#
# Get Image Min and Max.
#
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
# New image width = 2105 height = 2403 bands = 1
#
# Opening Clumps Image: IHS_2022_10_RGB832_uas_05m_segs.kea
# Opening Input Image: train_tmp/CombinedClasses_eb30f980ec.kea
#
#
# Min 0
# Max 4
# Range 5
# [0, 1, 2, 3, 4]
#
# Deleting file: train_tmp/pastos_limpios_eb30f980ec.kea
# Deleting file: train_tmp/pastos_espacios_naturales_eb30f980ec.kea
# Deleting file: train_tmp/lagunas_lagos_cienagas_naturales_eb30f980ec.kea
# Deleting file: train_tmp/arbustal_eb30f980ec.kea
# Deleting file: train_tmp/CombinedClasses_eb30f980ec.kea

# %%
# Columns to be extracted and used for classification
cols = [
    "blue_refl",
    "green_refl",
    "nir_b8_refl"
]

# Reading classification column from RAT.
class_int_smpls_col = rsgislib.rastergis.get_column_data(out_clumps_img, "class_int_smpls")
# Get the unique classes (i.e., there are samples for the class)
unq_classes = numpy.unique(class_int_smpls_col)

cls_smpls_clumps_info = dict()

# Loop through each of the classes to extract the samples to a HDF5
for class_vec_sample in class_vec_sample_clumps_info:
    print("{}:".format(class_vec_sample.class_name))
    # Check the class is within the list of unique classes
    if class_vec_sample.id in unq_classes:
        # Extract the class samples to a HDF5 file
        rsgislib.classification.classratutils.extract_rat_col_data(
            out_clumps_img,
            cols,
            "class_int_smpls",
            class_vec_sample.id,
            class_vec_sample.file_h5,
            datatype=rsgislib.TYPE_32FLOAT,
        )
        cls_smpls_clumps_info[
            class_vec_sample.class_name
        ] = rsgislib.classification.ClassSimpleInfoObj(
            id=class_vec_sample.id, file_h5=class_vec_sample.file_h5
        )
# Out:
# pastos_limpios:
# n feats: 97
# n cols: 3
# pastos_espacios_naturales:
# n feats: 93
# n cols: 3
# lagunas_lagos_cienagas_naturales:
# n feats: 40
# n cols: 3
# arbustal:
# n feats: 84
# n cols: 3

# %%
class_vec_sample_pixels_info = list()

# Define the file name of the samples HDF5 file, which will be created
pastos_limpios_pixels_h5 = "pastos_limpios_smpls_pixels.h5"
class_vec_sample_pixels_info.append(
    rsgislib.classification.ClassVecSamplesInfoObj(
        id=1,
        class_name="pastos_limpios",
        vec_file=vec_train_file,
        vec_lyr="pastos_limpios",
        file_h5=pastos_limpios_pixels_h5,
    )
)

# Define the file name of the samples HDF5 file, which will be created
pastos_espacios_naturales_pixels_h5 = "pastos_espacios_naturales_smpls_pixels.h5"
class_vec_sample_pixels_info.append(
    rsgislib.classification.ClassVecSamplesInfoObj(
        id=2,
        class_name="pastos_espacios_naturales",
        vec_file=vec_train_file,
        vec_lyr="pastos_espacios_naturales",
        file_h5=pastos_espacios_naturales_pixels_h5,
    )
)


# Define the file name of the samples HDF5 file, which will be created
lagunas_lagos_cienagas_naturales_pixels_h5 = "lagunas_lagos_cienagas_naturales_smpls_pixels.h5"
class_vec_sample_pixels_info.append(
    rsgislib.classification.ClassVecSamplesInfoObj(
        id=3,
        class_name="lagunas_lagos_cienagas_naturales",
        vec_file=vec_train_file,
        vec_lyr="lagunas_lagos_cienagas_naturales",
        file_h5=lagunas_lagos_cienagas_naturales_pixels_h5,
    )
)

# Define the file name of the samples HDF5 file, which will be created
arbustal_pixels_h5 = "arbustal_smpls_pixels.h5"
class_vec_sample_pixels_info.append(
    rsgislib.classification.ClassVecSamplesInfoObj(
        id=4,
        class_name="arbustal",
        vec_file=vec_train_file,
        vec_lyr="arbustal",
        file_h5=arbustal_pixels_h5,
    )
)

img_band_info = list()
img_band_info.append(
    rsgislib.imageutils.ImageBandInfo(
        file_name=input_img, name="sen2", bands=[3, 2, 1]
    )
)

cls_smpls_pixel_info = rsgislib.classification.get_class_training_data(
    img_band_info, class_vec_sample_pixels_info, tmp_train_dir, ref_img=input_img
)
# Out:
# Creating output image using input image
# Writing Stats to RAT
#
# Running Rasterise now...
# Get Image Min and Max.
#
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
#
# Creating output image using input image
# Running Rasterise now...
#
# Get Image Min and Max.
#
# Creating output image using input image
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
#
#
# Running Rasterise now...
# Get Image Min and Max.
#
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
#
# Creating output image using input image
# Running Rasterise now...
#
# Get Image Min and Max.
#
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.

# %%
print("Number of Samples:")
cls_smpls_info = dict()
for class_name in cls_smpls_pixel_info:
    h5_files = [cls_smpls_pixel_info[class_name].file_h5]
    if class_name in cls_smpls_clumps_info:
        h5_files.append(cls_smpls_clumps_info[class_name].file_h5)

    out_file_h5 = cls_smpls_pixel_info[class_name].file_h5.replace("_pixels", "")
    rsgislib.zonalstats.merge_extracted_hdf5_data(
        h5_files, out_file_h5, datatype=rsgislib.TYPE_32FLOAT
    )
    cls_smpls_info[class_name] = rsgislib.classification.ClassSimpleInfoObj(
        id=cls_smpls_pixel_info[class_name].id,
        file_h5=out_file_h5,
        blue=cls_smpls_pixel_info[class_name].blue,
        green=cls_smpls_pixel_info[class_name].green,
        red=cls_smpls_pixel_info[class_name].red,
    )

    print(
        "\t{}: {}".format(
            class_name, rsgislib.classification.get_num_samples(out_file_h5)
        )
    )
# Out:
# Number of Samples:
# 	pastos_limpios: 197
# 	pastos_espacios_naturales: 193
# 	lagunas_lagos_cienagas_naturales: 140
# 	arbustal: 184

# %%
cls_smpls_info["pastos_limpios"].red = 190
cls_smpls_info["pastos_limpios"].green = 192
cls_smpls_info["pastos_limpios"].blue = 146

cls_smpls_info["pastos_espacios_naturales"].red = 44
cls_smpls_info["pastos_espacios_naturales"].green = 168
cls_smpls_info["pastos_espacios_naturales"].blue = 128

cls_smpls_info["lagunas_lagos_cienagas_naturales"].red = 109
cls_smpls_info["lagunas_lagos_cienagas_naturales"].green = 219
cls_smpls_info["lagunas_lagos_cienagas_naturales"].blue = 215

cls_smpls_info["arbustal"].red = 137
cls_smpls_info["arbustal"].green = 214
cls_smpls_info["arbustal"].blue = 49

# %%
smpls_dir = "cls_smpls"
if not os.path.exists(smpls_dir):
    os.mkdir(smpls_dir)

cls_smpls_fnl_info = rsgislib.classification.get_class_info_dict(
    cls_smpls_info, smpls_dir
)

# Run the create_train_valid_test_sets helper function to
# create the train, valid and test datasets
rsgislib.classification.create_train_valid_test_sets(
    cls_smpls_info, cls_smpls_fnl_info, 10, 10, 100
)
# Out:
# 0=1: (Train:cls_smpls/pastos_limpios_smpls_train.h5, Test:cls_smpls/pastos_limpios_smpls_test.h5, Valid:cls_smpls/pastos_limpios_smpls_valid.h5), (190, 192, 146)
# 1=2: (Train:cls_smpls/pastos_espacios_naturales_smpls_train.h5, Test:cls_smpls/pastos_espacios_naturales_smpls_test.h5, Valid:cls_smpls/pastos_espacios_naturales_smpls_valid.h5), (44, 168, 128)
# 2=3: (Train:cls_smpls/lagunas_lagos_cienagas_naturales_smpls_train.h5, Test:cls_smpls/lagunas_lagos_cienagas_naturales_smpls_test.h5, Valid:cls_smpls/lagunas_lagos_cienagas_naturales_smpls_valid.h5), (109, 219, 215)
# 3=4: (Train:cls_smpls/arbustal_smpls_train.h5, Test:cls_smpls/arbustal_smpls_test.h5, Valid:cls_smpls/arbustal_smpls_valid.h5), (137, 214, 49)

# %%
grid_search = GridSearchCV(
    RandomForestClassifier(),
    param_grid={
        "n_estimators": [10, 20, 50, 100],
        "max_depth": [4, 8, 10, 12],
    },
)

sk_classifier = (
    rsgislib.classification.classsklearn.perform_sklearn_classifier_param_search(
        cls_smpls_fnl_info, grid_search
    )
)
# Out:
# Training data size: 40 x 3
# Best score was 0.65 and has parameters {'max_depth': 8, 'n_estimators': 10}.

# %%
rsgislib.classification.classsklearn.train_sklearn_classifier(
    cls_smpls_fnl_info, sk_classifier
)
# Out:
# Training data size: 400 x 3
# Testing data size: 40 x 3
# Training Classifier
# Completed
# Calc Classifier Accuracy
# Classifier Train Score = 91.5%
# Classifier Test Score = 57.5%
# (0.915, 0.575)

# %%
rsgislib.classification.classsklearn.apply_sklearn_classifier_rat(
    out_clumps_img,
    cols,
    sk_classifier,
    cls_smpls_fnl_info,
    out_col_int="class_id",
    out_col_str="class_names",
)

# %%
out_cls_img = "uas_05m_clumps_cls_rslt.kea"

rsgislib.classification.collapse_classes(
    out_clumps_img,
    out_cls_img,
    gdalformat="KEA",
    class_col="class_names",
    class_int_col="class_id",
)
# Out:
# Opening an image
# Find the class names...
#
# 4:	 arbustal: [137,214,49]
# 3:	 lagunas_lagos_cienagas_naturales: [109,219,215]
# 2:	 pastos_espacios_naturales: [44,168,128]
# 1:	 pastos_limpios: [190,192,146]
# New image width = 2105 height = 2403 bands = 1

# %%
# Create the matplotlib figure
fig, ax = plt.subplots(figsize=(10, 10))

rsgislib.tools.mapping.create_thematic_raster_map(ax, out_cls_img)
# Out:
# Image Data Size: 2105 x 2403

# %%
cls_info = rsgislib.tools.plotting.create_legend_info_dict(
    out_cls_img,
    cls_names_col="class_names",
    use_title_case=True,
    underscore_to_space=True,
)

# %%
out_cls_img_1 = "uas_05m_clumps_cls_rslt.tif"

rsgislib.classification.collapse_classes(
    out_clumps_img,
    out_cls_img_1,
    gdalformat="GTiff",
    class_col="class_names",
    class_int_col="class_id",
)
# Out:
# Opening an image
# Find the class names...
#
# 4:	 arbustal: [137,214,49]
# 3:	 lagunas_lagos_cienagas_naturales: [109,219,215]
# 2:	 pastos_espacios_naturales: [44,168,128]
# 1:	 pastos_limpios: [190,192,146]
# New image width = 2105 height = 2403 bands = 1

# %%
# Define a bbox for the subset to be displayed
sub_img_bbox = [0, 4919962, 0, 2119879]

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 8), sharey=False)
# Add the Sentinel-2 image to the axis
rsgislib.tools.mapping.create_raster_img_map(
    ax1,
    input_img,
    img_bands=[3, 2, 1],
    img_stch=rsgislib.IMG_STRECTH_CUMULATIVE,
    bbox=sub_img_bbox,
    show_scale_bar=True,
)
ax1.title.set_text("Input Image")

# Add the classification to the second axis.
rsgislib.tools.mapping.create_thematic_raster_map(ax2, out_cls_img, bbox=sub_img_bbox)
ax2.title.set_text("Classification Result")

rsgislib.tools.plotting.create_legend_img_mpl_ax(ax3, legend_info=cls_info, n_cols=2)
# Out:
# Image Data Size: 2105 x 2402
# Image Data Size: 2105 x 2402
# Max. characters in class name: 32
# Column width: 204
# Image: 420 x  58
