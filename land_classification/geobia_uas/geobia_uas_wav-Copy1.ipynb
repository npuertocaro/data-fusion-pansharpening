# %% [markdown]
# # Introduction
#
# This notebook will go through the steps to undertake a classification using a segmentation rather than a pixel based classification.
#
# A number of studies have proposed that segmenting an image and classifying the segments can produce a better classification result than classifying individual pixels.
#
# The notebook will go through the following steps:
#
# Perform segmentation
# Populate segments with data
# Extract sample data
# Split sample data into training, testing and validation sets
# Training Classifier
# Apply Classifier
# Running Notebook
# The notebook has been run and saved with the outputs so you can see what the outputs should be and so the notebook and be browsed online without having to run the notebook for it to make sense.
#
# If you are running the notebook for yourself it is recommended that you clear the existing outputs which can be done by running one of the following options depending on what system you are using:
#
# ### Jupyter-lab:
#
# > Edit > 'Clear All Outputs'
#
# ### Jupyter-notebook:
#
# > Cell > 'All Outputs' > Clear

# %% [markdown]
# ### Fuente:
#
# Código adaptado de RSGISLib Tutorials
# Repositorio: https://github.com/remotesensinginfo/rsgislib-tutorials
# Segmentación: https://github.com/remotesensinginfo/rsgislib-tutorials/blob/main/03_intro_image_classification/02_segment_ml_classification.ipynb

# %%
# Import modules from python standard library
import os
import pprint
import random

# Import the matplotlib plotting module and set it to work within
# a notebook environment.

import matplotlib
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt

# Import the RSGISLib modules for the notebook
import rsgislib
import rsgislib.classification
import rsgislib.classification.classratutils
import rsgislib.classification.classsklearn
import rsgislib.rastergis
import rsgislib.tools.filetools
import rsgislib.tools.mapping
import rsgislib.vectorutils
import rsgislib.vectorutils.createrasters
import rsgislib.zonalstats
from rsgislib.segmentation import shepherdseg
from sklearn.ensemble import RandomForestClassifier

# Import the geopandas module
os.environ["USE_PYGEOS"] = "0"
import geopandas

# Import the numpy module
import numpy

# scikit-learn imports
from sklearn.model_selection import GridSearchCV

# %%
input_img = "/Users/felipehernandez/Documents/Natalia/Desarrollo/Repos/data/fusion_satelite_uav/processed_images/uas_05m/wavelet/RGB832/WAV_2022_10_RGB832_uas_05m.tif"

# Create a plot using the matplotlib library
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the image data using bands 8, 9, 3 (NIR, SWIR1, Red)
# which produces a good false colour visualisation which is
# good at picking out vegetation. If you want a true colour
# (i.e., Red, Green, Blue) visualisation change the bands to
# [3, 2, 1]

rsgislib.tools.mapping.create_raster_img_map(ax, 
                                             input_img, 
                                             img_bands=[3, 2, 1], 
                                             img_stch=rsgislib.IMG_STRETCH_STDEV)
# Out:
# Image Data Size: 2105 x 2403
# /Users/felipehernandez/anaconda3/lib/python3.11/site-packages/matplotlib/cm.py:494: RuntimeWarning: invalid value encountered in cast
#   xx = (xx * 255).astype(np.uint8)

# %%
out_clumps_img = "WAV_2022_10_RGB832_uas_05m_segs.kea"
out_mean_img = "WAV_2022_10_RGB832_uas_05m_meanimg.kea"
tmp_dir = "tmp"

shepherdseg.run_shepherd_segmentation(
    input_img,
    out_clumps_img,
    out_mean_img,
    tmp_dir,
    gdalformat="KEA",  
    calc_stats=True,
    no_stretch=False,  
    no_delete=False,  
    num_clusters=60,  
    min_n_pxls=100,  
    dist_thres=100,
    bands=[3, 2, 1], 
    sampling=100,  
    km_max_iter=200, 
    process_in_mem=True,  
    save_process_stats=False,
    img_stretch_stats="",
    kmeans_centres="",
    img_stats_json_file="",
)
# Out:
# Subsetting the image bands
# New image width = 2105 height = 2403 bands = 3
#
# Stretch Input Image
#
#
# Band[1] Min = 0 Mean = 16.3813681542 (Std Dev = 15.5351002837) max = 255
# Band[2] Min = 0 Mean = 18.3418961379 (Std Dev = 16.9518610634) max = 255
# Band[3] Min = 0 Mean = 37.3621112603 (Std Dev = 41.4015725541) max = 255
# New image width = 2105 height = 2403 bands = 3
#
# Add 1 to stretched file to ensure there are no all zeros (i.e., no data) regions created.
# Create Input Image Mask.
# Mask stretched Image.
# New image width = 2105 height = 2403 bands = 3
#
# Image: tmp/WAV_2022_10_RGB832_uas_05m_bselect.kea
# 	 Variable 'b1' is band 1
# New image width = 2105 height = 2403 bands = 1
#
# New image width = 2105 height = 2403 bands = 3
#
# Deleting file: tmp/WAV_2022_10_RGB832_uas_05m_stchdonly.kea
# Deleting file: tmp/WAV_2022_10_RGB832_uas_05m_stchdonly_off.kea
# Deleting file: tmp/WAV_2022_10_RGB832_uas_05m_stchdmaskonly.kea
# Performing KMeans.
# inputImage = tmp/WAV_2022_10_RGB832_uas_05m_stchd.kea
# outputMatrixFile = tmp/WAV_2022_10_RGB832_uas_05m_kmeansclusters
# Apply KMeans to image.
# Eliminate Single Pixels.
# Perform clump.
# Eliminate small pixels.
# numClusters = 60
# maxNumIterations = 200
# subSample = 100
# degreeOfChange = 0.00249999994412
# Ignoring Zeros
# Full diag attached.
# Subsampling the image to read into memory
# Performing clustering
# Starting Iterative processing...
# Iteration 0 has change 44.2094039917 % of data clump IDs (60 clusters).
# Iteration 1 has change 16.6483650208 % of data clump IDs (60 clusters).
# Iteration 2 has change 9.88244438171 % of data clump IDs (60 clusters).
# Iteration 3 has change 7.40214443207 % of data clump IDs (60 clusters).
# Iteration 4 has change 5.68079042435 % of data clump IDs (60 clusters).
# Iteration 5 has change 4.69254636765 % of data clump IDs (60 clusters).
# Iteration 6 has change 3.86900901794 % of data clump IDs (60 clusters).
# Iteration 7 has change 3.32321405411 % of data clump IDs (60 clusters).
# Iteration 8 has change 2.80648493767 % of data clump IDs (60 clusters).
# Iteration 9 has change 2.76773023605 % of data clump IDs (60 clusters).
# Iteration 10 has change 2.64823651314 % of data clump IDs Relabel clumps.
# (60 clusters).
# Iteration 11 has change 2.33174014091 % of data clump IDs (60 clusters).
# Iteration 12 has change 2.16380310059 % of data clump IDs (60 clusters).
# Iteration 13 has change 2.18640995026 % of data clump IDs (60 clusters).
# Iteration 14 has change 1.98940706253 % of data clump IDs (60 clusters).
# Iteration 15 has change 1.81824064255 % of data clump IDs (60 clusters).
# Iteration 16 has change 1.62446701527 % of data clump IDs (60 clusters).
# Iteration 17 has change 1.16264045238 % of data clump IDs (60 clusters).
# Iteration 18 has change 1.07867193222 % of data clump IDs (60 clusters).
# Iteration 19 has change 1.14326322079 % of data clump IDs (60 clusters).
# Iteration 20 has change 0.949489712715 % of data clump IDs (60 clusters).
# Iteration 21 has change 0.97209662199 % of data clump IDs (60 clusters).
# Iteration 22 has change 0.959178447723 % of data clump IDs (60 clusters).
# Iteration 23 has change 1.17555880547 % of data clump IDs (60 clusters).
# Iteration 24 has change 1.14326322Calculate image statistics and build pyramids.
# 079 % of data clump IDs (60 clusters).
# Iteration 25 has change 0.90427595377 % of data clump IDs (60 clusters).
# Iteration 26 has change 0.871980369091 % of data clump IDs (60 clusters).
# Iteration 27 has change 0.849373459816 % of data clump IDs (60 clusters).
# Iteration 28 has change 0.988244473934 % of data clump IDs (60 clusters).
# Iteration 29 has change 0.849373459816 % of data clump IDs (60 clusters).
# Iteration 30 has change 0.978555738926 % of data clump IDs (60 clusters).
# Iteration 31 has change 0.978555738926 % of data clump IDs (60 clusters).
# Iteration 32 has change 0.930112421513 % of data clump IDs (60 clusters).
# Iteration 33 has change 0.894587278366 % of data clump IDs (60 clusters).
# Iteration 34 has change 0.810618817806 % of data clump IDs (60 clusters).
# Iteration 35 has change 0.762175440788 % of data clump IDs (60 clusters).
# Iteration 36 has change 0.678206920624 % of data clump IDs (60 clusters).
# Iteration 37 has change 0.700813829899 % of data clump IDs (60 clusters).
# Iteration 38 has change 0.671747863293 % of data clump IDs (60 clusters).
# Iteration 39 has change 0.671747863293 % of data clump IDs (60 clusters).
# Iteration 40 has change 0.64591139555 % of data clump IDs (60 clusters).
# Iteration 41 has change 0.600697577 % of data clump IDs (60 clusters).
# Iteration 42 has change 0.72987985611 % of data clump IDs (60 clusters).
# Iteration 43 has change 0.671747863293 % of data clump IDs (60 clusters).
# Iteration 44 has change 0.649140894413 % of data clump IDs (60 clusters).
# Iteration 45 has change 0.610386252403 % of data clump IDs (60 clusters).
# Iteration 46 has change 0.594238460064 % of data clump IDs (60 clusters).
# Iteration 47 has change 0.684666097164 % of data clump IDs (60 clusters).
# Iteration 48 has change 0.626534044743 % of data clump IDs (60 clusters).
# Iteration 49 has change 0.62976360321 % of data clump IDs (60 clusters).
# Iteration 50 has change 0.649140894413 % of data clump IDs (60 clusters).
# Iteration 51 has change 0.736338973045 % of Deleting file: tmp/WAV_2022_10_RGB832_uas_05m_kmeansclusters.gmtxt
# data clump IDs (60 clusters).
# Iteration 52 has change 0.807389259338 % of data clump IDs (60 clusters).
# Iteration 53 has change 0.778323233128 % of data clump IDs (60 clusters).
# Iteration 54 has change 0.846143901348 % of data clump IDs (60 clusters).
# Iteration 55 has change 0.652370512486 % of data clump IDs (60 clusters).
# Iteration 56 has change 0.600697577 % of data clump IDs (60 clusters).
# Iteration 57 has change 0.545795142651 % of data clump IDs (60 clusters).
# Iteration 58 has change 0.742798089981 % of data clump IDs (60 clusters).
# Iteration 59 has change 0.888128101826 % of data clump IDs (60 clusters).
# Iteration 60 has change 1.04314684868 % of data clump IDs (60 clusters).
# Iteration 61 has change 1.01408088207 % of data clump IDs (60 clusters).
# Iteration 62 has change 0.901046395302 % of data clump IDs (60 clusters).
# Iteration 63 has change 0.878439486027 % of data clump IDs (60 clusters).
# Iteration 64 has change 0.981785237789 % of data clump IDs (60 clusters).
# Iteration 65 has change 1.02699911594 % of data clump IDs (60 clusters).
# Iteration 66 has change 0.891357660294 % of data clump IDs (60 clusters).
# Iteration 67 has change 0.72987985611 % of data clump IDs (60 clusters).
# Iteration 68 has change 1.14326322079 % of data clump IDs (60 clusters).
# Iteration 69 has change 0.807389259338 % of data clump IDs (60 clusters).
# Iteration 70 has change 0.400465071201 % of data clump IDs (60 clusters).
# Iteration 71 has change 0.397235482931 % of data clump IDs (60 clusters).
# Iteration 72 has change 0.439219743013 % of data clump IDs (60 clusters).
# Iteration 73 has change 0.542565584183 % of data clump IDs (60 clusters).
# Iteration 74 has change 0.613615810871 % of data clump IDs (60 clusters).
# Iteration 75 has change 0.600697577 % of data clump IDs (60 clusters).
# Iteration 76 has change 0.532876908779 % of data clump IDs (60 clusters).
# Iteration 77 has change 0.406924158335 % of data clump IDs (60 clusters).
# Iteration 78 has change 0.45536750555 % of data clump IDsDeleting file: tmp/WAV_2022_10_RGB832_uas_05m_kmeans.kea.aux.xml
#  (60 clusters).
# Iteration 79 has change 0.458597064018 % of data clump IDs (60 clusters).
# Iteration 80 has change 0.419842392206 % of data clump IDs (60 clusters).
# Iteration 81 has change 0.287430584431 % of data clump IDs (60 clusters).
# Iteration 82 has change 0.284200996161 % of data clump IDs (60 clusters).
# Iteration 83 has change 0.264823675156 % of data clump IDs (60 clusters).
# Iteration 84 has change 0.374628603458 % of data clump IDs (60 clusters).
# Iteration 85 has change 0.268053203821 % of data clump IDs (60 clusters).
# Iteration 86 has change 0.21638032794 % of data clump IDs (60 clusters).
# Exporting cluster centres to output file
# New image width = 2105 height = 2403 bands = 1
#
# Eliminating Individual Pixels
#
# There are 467107 single pixels within the image
#
#
# There are 11238 single pixels within the image
#
#
# There are 54 single pixels within the image
#
#
# Complete, all connected single pixels have been removed
# Processing in Memory
# Performing Clump
#
#
# (Generated 237528 clumps).
# Copying output to disk
# Processing in Memory
# Eliminant Clumps
# Calc Number of clumps
#
# Build clump table
# Calculate Initial Clump Means
# There are 237528 clumps.
# Eliminating Small Clumps.
# Eliminating clumps of size 1
# Found 0 small clumps to be eliminated.
# Eliminated 0 small clumps
# Eliminating clumps of size 2
# Found 49822 small clumps to be eliminated.
# Eliminated 49822 small clumps
# Eliminating clumps of size 3
# Found 37729 small clumps to be eliminated.
# Eliminated 87551 small clumps
# Eliminating clumps of size 4
# Found 26528 small clumps to be eliminated.
# Eliminated 114079 small clumps
# Eliminating clumps of size 5
# Found 18950 small clumps to be eliminated.
# Eliminated 133029 small clumps
# Eliminating clumps of size 6
# Found 12637 small clumps to be eliminated.
# Eliminated 145666 small clumps
# Eliminating clumps of size 7
# Found 11000 small clumps to be eliminated.
# Eliminated 156666 small clumps
# Eliminating clumps of size 8
# Found 8364 small clumps to be eliminated.
# Eliminated 165030 small clumps
# Eliminating clumps of size 9
# Found 7718 small clumps to be eliminated.
# Eliminated 172748 small clumps
# Eliminating clumps of size 10
# Found 5914 small clumps to be eliminated.
# Eliminated 178662 small clumps
# Eliminating clumps of size 11
# Found 5636 small clumps to be eliminated.
# Eliminated 184298 small clumps
# Eliminating clumps of size 12
# Found 4788 small clumps to be eliminated.
# Eliminated 189086 small clumps
# Eliminating clumps of size 13
# Found 4641 small clumps to be eliminated.
# Eliminated 193727 small clumps
# Eliminating clumps of size 14
# Found 4055 small clumps to be eliminated.
# Eliminated 197782 small clumps
# Eliminating clumps of size 15
# Found 3854 small clumps to be eliminated.
# Eliminated 201636 small clumps
# Eliminating clumps of size 16
# Found 3444 small clumps to be eliminated.
# Eliminated 205080 small clumps
# Eliminating clumps of size 17
# Found 3415 small clumps to be eliminated.
# Eliminated 208495 small clumps
# Eliminating clumps of size 18
# Found 3139 small clumps to be eliminated.
# Eliminated 211634 small clumps
# Eliminating clumps of size 19
# Found 2956 small clumps to be eliminated.
# Eliminated 214590 small clumps
# Eliminating clumps of size 20
# Found 2810 small clumps to be eliminated.
# Eliminated 217400 small clumps
# Eliminating clumps of size 21
# Found 2740 small clumps to be eliminated.
# Eliminated 220140 small clumps
# Eliminating clumps of size 22
# Found 2568 small clumps to be eliminated.
# Eliminated 222708 small clumps
# Eliminating clumps of size 23
# Found 2526 small clumps to be eliminated.
# Eliminated 225234 small clumps
# Eliminating clumps of size 24
# Found 2462 small clumps to be eliminated.
# Eliminated 227696 small clumps
# Eliminating clumps of size 25
# Found 2354 small clumps to be eliminated.
# Eliminated 230050 small clumps
# Eliminating clumps of size 26
# Found 2316 small clumps to be eliminated.
# Eliminated 232366 small clumps
# Eliminating clumps of size 27
# Found 2252 small clumps to be eliminated.
# Eliminated 234618 small clumps
# Eliminating clumps of size 28
# Found 2181 small clumps to be eliminated.
# Eliminated 236799 small clumps
# Eliminating clumps of size 29
# Found 2182 small clumps to be eliminated.
# Eliminated 238981 small clumps
# Eliminating clumps of size 30
# Found 2089 small clumps to be eliminated.
# Eliminated 241070 small clumps
# Eliminating clumps of size 31
# Found 2123 small clumps to be eliminated.
# Eliminated 243193 small clumps
# Eliminating clumps of size 32
# Found 2033 small clumps to be eliminated.
# Eliminated 245226 small clumps
# Eliminating clumps of size 33
# Found 2002 small clumps to be eliminated.
# Eliminated 247228 small clumps
# Eliminating clumps of size 34
# Found 1982 small clumps to be eliminated.
# Eliminated 249210 small clumps
# Eliminating clumps of size 35
# Found 1959 small clumps to be eliminated.
# Eliminated 251169 small clumps
# Eliminating clumps of size 36
# Found 1885 small clumps to be eliminated.
# Eliminated 253054 small clumps
# Eliminating clumps of size 37
# Found 1938 small clumps to be eliminated.
# Eliminated 254992 small clumps
# Eliminating clumps of siDeleting file: tmp/WAV_2022_10_RGB832_uas_05m_kmeans.kea
# ze 38
# Found 1853 small clumps to be eliminated.
# Eliminated 256845 small clumps
# Eliminating clumps of size 39
# Found 1816 small clumps to be eliminated.
# Eliminated 258661 small clumps
# Eliminating clumps of size 40
# Found 1828 small clumps to be eliminated.
# Eliminated 260489 small clumps
# Eliminating clumps of size 41
# Found 1797 small clumps to be eliminated.
# Eliminated 262286 small clumps
# Eliminating clumps of size 42
# Found 1787 small clumps to be eliminated.
# Eliminated 264073 small clumps
# Eliminating clumps of size 43
# Found 1735 small clumps to be eliminated.
# Eliminated 265808 small clumps
# Eliminating clumps of size 44
# Found 1776 small clumps to be eliminated.
# Eliminated 267584 small clumps
# Eliminating clumps of size 45
# Found 1744 small clumps to be eliminated.
# Eliminated 269328 small clumps
# Eliminating clumps of size 46
# Found 1709 small clumps to be eliminated.
# Eliminated 271037 small clumps
# Eliminating clumps of size 47
# Found 1730 small clumps to be eliminated.
# Eliminated 272767 small clumps
# Eliminating clumps of size 48
# Found 1692 small clumps to be eliminated.
# Eliminated 274459 small clumps
# Eliminating clumps of size 49
# Found 1682 small clumps to be eliminated.
# Eliminated 276141 small clumps
# Eliminating clumps of size 50
# Found 1676 small clumps to be eliminated.
# Eliminated 277817 small clumps
# Eliminating clumps of size 51
# Found 1716 small clumps to be eliminated.
# Eliminated 279533 small clumps
# Eliminating clumps of size 52
# Found 1674 small clumps to be eliminated.
# Eliminated 281207 small clumps
# Eliminating clumps of size 53
# Found 1657 small clumps to be eliminated.
# Eliminated 282864 small clumps
# Eliminating clumps of size 54
# Found 1673 small clumps to be eliminated.
# Eliminated 284537 small clumps
# Eliminating clumps of size 55
# Found 1629 small clumps to be eliminated.
# Eliminated 286166 small clumps
# Eliminating clumps of size 56
# Found 1661 small clumps to be eliminated.
# Eliminated 287827 small clumps
# Eliminating clumps of size 57
# Found 1638 small clumps to be eliminated.
# Eliminated 289465 small clumps
# Eliminating clumps of size 58
# Found 1617 small clumps to be eliminated.
# Eliminated 291082 small clumps
# Eliminating clumps of size 59
# Found 1613 small clumps to be eliminated.
# Eliminated 292695 small clumps
# Eliminating clumps of size 60
# Found 1630 small clumps to be eliminated.
# Eliminated 294325 small clumps
# Eliminating clumps of size 61
# Found 1589 small clumps to be eliminated.
# Eliminated 295914 small clumps
# Eliminating clumps of size 62
# Found 1622 small clumps to be eliminated.
# Eliminated 297536 small clumps
# Eliminating clumps of size 63
# Found 1615 small clumps to be eliminated.
# Eliminated 299151 small clumps
# Eliminating clumps of size 64
# Found 1594 small clumps to be eliminated.
# Eliminated 300745 small clumps
# Eliminating clumps of size 65
# Found 1580 small clumps to be eliminated.
# Eliminated 302325 small clumps
# Eliminating clumps of size 66
# Found 1623 small clumps to be eliminated.
# Eliminated 303948 small clumps
# Eliminating clumps of size 67
# Found 1597 small clumps to be eliminated.
# Eliminated 305545 small clumps
# Eliminating clumps of size 68
# Found 1594 small clumps to be eliminated.
# Eliminated 307139 small clumps
# Eliminating clumps of size 69
# Found 1575 small clumps to be eliminated.
# Eliminated 308714 small clumps
# Eliminating clumps of size 70
# Found 1581 small clumps to be eliminated.
# Eliminated 310295 small clumps
# Eliminating clumps of size 71
# Found 1587 small clumps to be eliminated.
# Eliminated 311882 small clumps
# Eliminating clumps of size 72
# Found 1582 small clumps to be eliminated.
# Eliminated 313464 small clumps
# Eliminating clumps of size 73
# Found 1561 small clumps to be eliminated.
# Eliminated 315025 small clumps
# Eliminating clumps of size 74
# Found 1543 small clumps to be eliminated.
# Eliminated 316568 small clumps
# Eliminating clumps of size 75
# Found 1563 small clumps to be eliminated.
# Eliminated 318131 small clumps
# Eliminating clumps of size 76
# Found 1558 small clumps to be eliminated.
# Eliminated 319689 small clumps
# EliminaDeleting file: tmp/WAV_2022_10_RGB832_uas_05m_kmeans_nosgl.kea
# ting clumps of size 77
# Found 1551 small clumps to be eliminated.
# Eliminated 321240 small clumps
# Eliminating clumps of size 78
# Found 1548 small clumps to be eliminated.
# Eliminated 322788 small clumps
# Eliminating clumps of size 79
# Found 1541 small clumps to be eliminated.
# Eliminated 324329 small clumps
# Eliminating clumps of size 80
# Found 1537 small clumps to be eliminated.
# Eliminated 325866 small clumps
# Eliminating clumps of size 81
# Found 1547 small clumps to be eliminated.
# Eliminated 327413 small clumps
# Eliminating clumps of size 82
# Found 1536 small clumps to be eliminated.
# Eliminated 328949 small clumps
# Eliminating clumps of size 83
# Found 1538 small clumps to be eliminated.
# Eliminated 330487 small clumps
# Eliminating clumps of size 84
# Found 1532 small clumps to be eliminated.
# Eliminated 332019 small clumps
# Eliminating clumps of size 85
# Found 1557 small clumps to be eliminated.
# Eliminated 333576 small clumps
# Eliminating clumps of size 86
# Found 1536 small clumps to be eliminated.
# Eliminated 335112 small clumps
# Eliminating clumps of size 87
# Found 1535 small clumps to be eliminated.
# Eliminated 336647 small clumps
# Eliminating clumps of size 88
# Found 1528 small clumps to be eliminated.
# Eliminated 338175 small clumps
# Eliminating clumps of size 89
# Found 1525 small clumps to be eliminated.
# Eliminated 339700 small clumps
# Eliminating clumps of size 90
# Found 1530 small clumps to be eliminated.
# Eliminated 341230 small clumps
# Eliminating clumps of size 91
# Found 1511 small clumps to be eliminated.
# Eliminated 342741 small clumps
# Eliminating clumps of size 92
# Found 1484 small clumps to be eliminated.
# Eliminated 344225 small clumps
# Eliminating clumps of size 93
# Found 1514 small clumps to be eliminated.
# Eliminated 345739 small clumps
# Eliminating clumps of size 94
# Found 1508 small clumps to be eliminated.
# Eliminated 347247 small clumps
# Eliminating clumps of size 95
# Found 1503 small clumps to be eliminated.
# Eliminated 348750 small clumps
# Eliminating clumps of size 96
# Found 1502 small cluDeleting file: tmp/WAV_2022_10_RGB832_uas_05m_clumps.kea
# mps to be eliminated.
# Eliminated 350252 small clumps
# Eliminating clumps of size 97
# Found 1495 small clumps to be eliminated.
# Eliminated 351747 small clumps
# Eliminating clumps of size 98
# Found 1490 small clumps to be eliminated.
# Eliminated 353237 small clumps
# Eliminating clumps of size 99
# Found 1502 small clumps to be eliminated.
# Eliminated 354739 small clumps
# Eliminating clumps of size 100
# Found 1499 small clumps to be eliminated.
# Eliminated 356238 small clumps
# Finshed Elimination. 356238 small clumps eliminated
# Copying output to disk
# Opening clumps file: tmp/WAV_2022_10_RGB832_uas_05m_clumps_elim.kea
# Processing in Memory
# Performing relabel
# Finding maximum image value
#
# Creating Look up table.
#
# Applying Look up table.
#
# Copying output to disk
# Get Image Min and Max.
#
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
# Processing using Disk
# Calculating Mean Image
# Finding maximum image value
#
# Build clump table
# Creating Look up table.
#
# Applying Look up table.
#
#
#
# Calculating Image Pyramids.
#
#
#
# Deleting file: tmp/WAV_2022_10_RGB832_uas_05m_clumps_elim.kea
# Deleting file: tmp/WAV_2022_10_RGB832_uas_05m_bselect.kea
# Deleting file: tmp/WAV_2022_10_RGB832_uas_05m_stchd.kea

# %%
import rsgislib.vectorutils.createvectors

segs_vec_file = "WAV_2022_10_RGB832_uas_05m_segs.gpkg"
segs_vec_lyr = "WAV_2022_10_RGB832_uas_05m_segs"

rsgislib.vectorutils.createvectors.polygonise_raster_to_vec_lyr(
    out_vec_file=segs_vec_file,  # The output vector file name and path
    out_vec_lyr=segs_vec_lyr,  # The output vector layer name
    out_format="GPKG",  # The output vector format
    input_img=out_clumps_img,  # The input segmentation image
    img_band=1,  # The band within the input image
    mask_img=out_clumps_img,  # A mask image (usually the same as the input image)
    mask_band=1,  # The band within the mask image
)
# Out:
#   9%|███▊                                       | 9/100 [00:00<00:01, 46.49it/s]
# Polygonising...
#  96%|████████████████████████████████████████▎ | 96/100 [00:07<00:00, 22.86it/s]
# Completed
# 101it [00:07, 13.19it/s]

# %%
bs = []
bs.append(rsgislib.rastergis.BandAttStats(band=1, mean_field="blue_refl"))
bs.append(rsgislib.rastergis.BandAttStats(band=2, mean_field="green_refl"))
bs.append(rsgislib.rastergis.BandAttStats(band=3, mean_field="nir_b8_refl"))
rsgislib.rastergis.populate_rat_with_stats(input_img, out_clumps_img, bs)
# Out:
# Writing Stats to RAT

# %%
# Create Training Rasterise tmp directory
tmp_train_dir = "train_tmp"
if not os.path.exists(tmp_train_dir):
    os.mkdir(tmp_train_dir)

vec_train_file = "/Users/felipehernandez/Documents/Natalia/Desarrollo/Repos/data/data_classification/entrenamiento.gpkg"

# Define Training Data
class_vec_sample_clumps_info = list()

# Define the file name of the samples HDF5 file, which will be created
pastos_limpios_clumps_h5 = "pastos_limpios_smpls_clumps.h5"
class_vec_sample_clumps_info.append(
    rsgislib.classification.ClassVecSamplesInfoObj(
        id=1,
        class_name="pastos_limpios",
        vec_file=vec_train_file,
        vec_lyr="pastos_limpios",
        file_h5=pastos_limpios_clumps_h5,
    )
)

# Define the file name of the samples HDF5 file, which will be created
pastos_espacios_naturales_clumps_h5 = "pastos_espacios_naturales_smpls_clumps.h5"
class_vec_sample_clumps_info.append(
    rsgislib.classification.ClassVecSamplesInfoObj(
        id=2,
        class_name="pastos_espacios_naturales",
        vec_file=vec_train_file,
        vec_lyr="pastos_espacios_naturales",
        file_h5=pastos_espacios_naturales_clumps_h5,
    )
)


# Define the file name of the samples HDF5 file, which will be created
lagunas_lagos_cienagas_naturales_clumps_h5 = "lagunas_lagos_cienagas_naturales_clumps.h5"
class_vec_sample_clumps_info.append(
    rsgislib.classification.ClassVecSamplesInfoObj(
        id=3,
        class_name="lagunas_lagos_cienagas_naturales",
        vec_file=vec_train_file,
        vec_lyr="lagunas_lagos_cienagas_naturales",
        file_h5=lagunas_lagos_cienagas_naturales_clumps_h5,
    )
)

# Define the file name of the samples HDF5 file, which will be created
arbustal_clumps_h5 = "arbustal_smpls_clumps.h5"
class_vec_sample_clumps_info.append(
    rsgislib.classification.ClassVecSamplesInfoObj(
        id=4,
        class_name="arbustal",
        vec_file=vec_train_file,
        vec_lyr="arbustal",
        file_h5=arbustal_clumps_h5,
    )
)

rsgislib.classification.classratutils.populate_clumps_with_class_training(
    out_clumps_img,
    class_vec_sample_clumps_info,
    tmp_train_dir,
    classes_int_col="class_int_smpls",
    classes_name_col="class_name_smpls",
)
# Out:
# Creating output image using input image
# Running Rasterise now...
# Writing Stats (Mean, ) to Output RAT
#
# Get Image Min and Max.
#
# Creating output image using input image
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
#
# Running Rasterise now...
# Get Image Min and Max.
#
# Creating output image using input image
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
#
# Running Rasterise now...
# Get Image Min and Max.
#
# Creating output image using input image
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
#
# Running Rasterise now...
# Get Image Min and Max.
#
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
# New image width = 2105 height = 2403 bands = 1
#
# Opening Clumps Image: WAV_2022_10_RGB832_uas_05m_segs.kea
# Opening Input Image: train_tmp/CombinedClasses_6b86c1f5da.kea
#
#
# Min 0
# Max 4
# Range 5
# [0, 1, 2, 3, 4]
#
# Deleting file: train_tmp/pastos_limpios_6b86c1f5da.kea
# Deleting file: train_tmp/pastos_espacios_naturales_6b86c1f5da.kea
# Deleting file: train_tmp/lagunas_lagos_cienagas_naturales_6b86c1f5da.kea
# Deleting file: train_tmp/arbustal_6b86c1f5da.kea
# Deleting file: train_tmp/CombinedClasses_6b86c1f5da.kea

# %%
# Columns to be extracted and used for classification
cols = [
    "blue_refl",
    "green_refl",
    "nir_b8_refl"
]

# Reading classification column from RAT.
class_int_smpls_col = rsgislib.rastergis.get_column_data(out_clumps_img, "class_int_smpls")
# Get the unique classes (i.e., there are samples for the class)
unq_classes = numpy.unique(class_int_smpls_col)

cls_smpls_clumps_info = dict()

# Loop through each of the classes to extract the samples to a HDF5
for class_vec_sample in class_vec_sample_clumps_info:
    print("{}:".format(class_vec_sample.class_name))
    # Check the class is within the list of unique classes
    if class_vec_sample.id in unq_classes:
        # Extract the class samples to a HDF5 file
        rsgislib.classification.classratutils.extract_rat_col_data(
            out_clumps_img,
            cols,
            "class_int_smpls",
            class_vec_sample.id,
            class_vec_sample.file_h5,
            datatype=rsgislib.TYPE_32FLOAT,
        )
        cls_smpls_clumps_info[
            class_vec_sample.class_name
        ] = rsgislib.classification.ClassSimpleInfoObj(
            id=class_vec_sample.id, file_h5=class_vec_sample.file_h5
        )
# Out:
# pastos_limpios:
# n feats: 97
# n cols: 3
# pastos_espacios_naturales:
# n feats: 98
# n cols: 3
# lagunas_lagos_cienagas_naturales:
# n feats: 33
# n cols: 3
# arbustal:
# n feats: 91
# n cols: 3

# %%
class_vec_sample_pixels_info = list()

# Define the file name of the samples HDF5 file, which will be created
pastos_limpios_pixels_h5 = "pastos_limpios_smpls_pixels.h5"
class_vec_sample_pixels_info.append(
    rsgislib.classification.ClassVecSamplesInfoObj(
        id=1,
        class_name="pastos_limpios",
        vec_file=vec_train_file,
        vec_lyr="pastos_limpios",
        file_h5=pastos_limpios_pixels_h5,
    )
)

# Define the file name of the samples HDF5 file, which will be created
pastos_espacios_naturales_pixels_h5 = "pastos_espacios_naturales_smpls_pixels.h5"
class_vec_sample_pixels_info.append(
    rsgislib.classification.ClassVecSamplesInfoObj(
        id=2,
        class_name="pastos_espacios_naturales",
        vec_file=vec_train_file,
        vec_lyr="pastos_espacios_naturales",
        file_h5=pastos_espacios_naturales_pixels_h5,
    )
)


# Define the file name of the samples HDF5 file, which will be created
lagunas_lagos_cienagas_naturales_pixels_h5 = "lagunas_lagos_cienagas_naturales_smpls_pixels.h5"
class_vec_sample_pixels_info.append(
    rsgislib.classification.ClassVecSamplesInfoObj(
        id=3,
        class_name="lagunas_lagos_cienagas_naturales",
        vec_file=vec_train_file,
        vec_lyr="lagunas_lagos_cienagas_naturales",
        file_h5=lagunas_lagos_cienagas_naturales_pixels_h5,
    )
)

# Define the file name of the samples HDF5 file, which will be created
arbustal_pixels_h5 = "arbustal_smpls_pixels.h5"
class_vec_sample_pixels_info.append(
    rsgislib.classification.ClassVecSamplesInfoObj(
        id=4,
        class_name="arbustal",
        vec_file=vec_train_file,
        vec_lyr="arbustal",
        file_h5=arbustal_pixels_h5,
    )
)

img_band_info = list()
img_band_info.append(
    rsgislib.imageutils.ImageBandInfo(
        file_name=input_img, name="sen2", bands=[3, 2, 1]
    )
)

cls_smpls_pixel_info = rsgislib.classification.get_class_training_data(
    img_band_info, class_vec_sample_pixels_info, tmp_train_dir, ref_img=input_img
)
# Out:
# Creating output image using input image
# Writing Stats to RAT
#
# Running Rasterise now...
# Get Image Min and Max.
#
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
#
# Creating output image using input image
# Running Rasterise now...
#
# Get Image Min and Max.
#
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
#
# Creating output image using input image
# Running Rasterise now...
#
# Get Image Min and Max.
#
# Creating output image using input image
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.
#
#
#
# Running Rasterise now...
# Get Image Min and Max.
#
# Get Image Histogram.
#
# Adding Histogram and Colour Table to image file
# Calculating Image Pyramids.

# %%
print("Number of Samples:")
cls_smpls_info = dict()
for class_name in cls_smpls_pixel_info:
    h5_files = [cls_smpls_pixel_info[class_name].file_h5]
    if class_name in cls_smpls_clumps_info:
        h5_files.append(cls_smpls_clumps_info[class_name].file_h5)

    out_file_h5 = cls_smpls_pixel_info[class_name].file_h5.replace("_pixels", "")
    rsgislib.zonalstats.merge_extracted_hdf5_data(
        h5_files, out_file_h5, datatype=rsgislib.TYPE_32FLOAT
    )
    cls_smpls_info[class_name] = rsgislib.classification.ClassSimpleInfoObj(
        id=cls_smpls_pixel_info[class_name].id,
        file_h5=out_file_h5,
        blue=cls_smpls_pixel_info[class_name].blue,
        green=cls_smpls_pixel_info[class_name].green,
        red=cls_smpls_pixel_info[class_name].red,
    )

    print(
        "\t{}: {}".format(
            class_name, rsgislib.classification.get_num_samples(out_file_h5)
        )
    )
# Out:
# Number of Samples:
# 	pastos_limpios: 197
# 	pastos_espacios_naturales: 198
# 	lagunas_lagos_cienagas_naturales: 133
# 	arbustal: 191

# %%
cls_smpls_info["pastos_limpios"].red = 190
cls_smpls_info["pastos_limpios"].green = 192
cls_smpls_info["pastos_limpios"].blue = 146

cls_smpls_info["pastos_espacios_naturales"].red = 44
cls_smpls_info["pastos_espacios_naturales"].green = 168
cls_smpls_info["pastos_espacios_naturales"].blue = 128

cls_smpls_info["lagunas_lagos_cienagas_naturales"].red = 109
cls_smpls_info["lagunas_lagos_cienagas_naturales"].green = 219
cls_smpls_info["lagunas_lagos_cienagas_naturales"].blue = 215

cls_smpls_info["arbustal"].red = 137
cls_smpls_info["arbustal"].green = 214
cls_smpls_info["arbustal"].blue = 49

# %%
smpls_dir = "cls_smpls"
if not os.path.exists(smpls_dir):
    os.mkdir(smpls_dir)

cls_smpls_fnl_info = rsgislib.classification.get_class_info_dict(
    cls_smpls_info, smpls_dir
)

# Run the create_train_valid_test_sets helper function to
# create the train, valid and test datasets
rsgislib.classification.create_train_valid_test_sets(
    cls_smpls_info, cls_smpls_fnl_info, 10, 10, 100
)
# Out:
# 0=1: (Train:cls_smpls/pastos_limpios_smpls_train.h5, Test:cls_smpls/pastos_limpios_smpls_test.h5, Valid:cls_smpls/pastos_limpios_smpls_valid.h5), (190, 192, 146)
# 1=2: (Train:cls_smpls/pastos_espacios_naturales_smpls_train.h5, Test:cls_smpls/pastos_espacios_naturales_smpls_test.h5, Valid:cls_smpls/pastos_espacios_naturales_smpls_valid.h5), (44, 168, 128)
# 2=3: (Train:cls_smpls/lagunas_lagos_cienagas_naturales_smpls_train.h5, Test:cls_smpls/lagunas_lagos_cienagas_naturales_smpls_test.h5, Valid:cls_smpls/lagunas_lagos_cienagas_naturales_smpls_valid.h5), (109, 219, 215)
# 3=4: (Train:cls_smpls/arbustal_smpls_train.h5, Test:cls_smpls/arbustal_smpls_test.h5, Valid:cls_smpls/arbustal_smpls_valid.h5), (137, 214, 49)

# %%
grid_search = GridSearchCV(
    RandomForestClassifier(),
    param_grid={
        "n_estimators": [10, 20, 50, 100],
        "max_depth": [4, 8, 10, 12],
    },
)

sk_classifier = (
    rsgislib.classification.classsklearn.perform_sklearn_classifier_param_search(
        cls_smpls_fnl_info, grid_search
    )
)
# Out:
# Training data size: 40 x 3
# Best score was 0.475 and has parameters {'max_depth': 8, 'n_estimators': 50}.

# %%
rsgislib.classification.classsklearn.train_sklearn_classifier(
    cls_smpls_fnl_info, sk_classifier
)
# Out:
# Training data size: 400 x 3
# Testing data size: 40 x 3
# Training Classifier
# Completed
# Calc Classifier Accuracy
# Classifier Train Score = 95.5%
# Classifier Test Score = 47.5%
# (0.955, 0.475)

# %%
rsgislib.classification.classsklearn.apply_sklearn_classifier_rat(
    out_clumps_img,
    cols,
    sk_classifier,
    cls_smpls_fnl_info,
    out_col_int="class_id",
    out_col_str="class_names",
)

# %%
out_cls_img = "uas_05m_clumps_cls_rslt.kea"

rsgislib.classification.collapse_classes(
    out_clumps_img,
    out_cls_img,
    gdalformat="KEA",
    class_col="class_names",
    class_int_col="class_id",
)
# Out:
# Opening an image
# Find the class names...
#
# 4:	 arbustal: [137,214,49]
# 3:	 lagunas_lagos_cienagas_naturales: [109,219,215]
# 2:	 pastos_espacios_naturales: [44,168,128]
# 1:	 pastos_limpios: [190,192,146]
# New image width = 2105 height = 2403 bands = 1

# %%
# Create the matplotlib figure
fig, ax = plt.subplots(figsize=(10, 10))

rsgislib.tools.mapping.create_thematic_raster_map(ax, out_cls_img)
# Out:
# Image Data Size: 2105 x 2403

# %%
cls_info = rsgislib.tools.plotting.create_legend_info_dict(
    out_cls_img,
    cls_names_col="class_names",
    use_title_case=True,
    underscore_to_space=True,
)

# %%
out_cls_img_1 = "uas_05m_clumps_cls_rslt.tif"

rsgislib.classification.collapse_classes(
    out_clumps_img,
    out_cls_img_1,
    gdalformat="GTiff",
    class_col="class_names",
    class_int_col="class_id",
)
# Out:
# Opening an image
# Find the class names...
#
# 4:	 arbustal: [137,214,49]
# 3:	 lagunas_lagos_cienagas_naturales: [109,219,215]
# 2:	 pastos_espacios_naturales: [44,168,128]
# 1:	 pastos_limpios: [190,192,146]
# New image width = 2105 height = 2403 bands = 1

# %%
# Define a bbox for the subset to be displayed
sub_img_bbox = [0, 4919962, 0, 2119879]

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 8), sharey=False)
# Add the Sentinel-2 image to the axis
rsgislib.tools.mapping.create_raster_img_map(
    ax1,
    input_img,
    img_bands=[3, 2, 1],
    img_stch=rsgislib.IMG_STRECTH_CUMULATIVE,
    bbox=sub_img_bbox,
    show_scale_bar=True,
)
ax1.title.set_text("Input Image")

# Add the classification to the second axis.
rsgislib.tools.mapping.create_thematic_raster_map(ax2, out_cls_img, bbox=sub_img_bbox)
ax2.title.set_text("Classification Result")

rsgislib.tools.plotting.create_legend_img_mpl_ax(ax3, legend_info=cls_info, n_cols=2)
# Out:
# Image Data Size: 2105 x 2402
# Image Data Size: 2105 x 2402
# Max. characters in class name: 32
# Column width: 204
# Image: 420 x  58
# /Users/felipehernandez/anaconda3/lib/python3.11/site-packages/matplotlib/cm.py:494: RuntimeWarning: invalid value encountered in cast
#   xx = (xx * 255).astype(np.uint8)

# %%
import rsgislib.vectorutils.createvectors

segs_vec_file_1 = "WAV_UAS_class.gpkg"
segs_vec_lyr_1 = "WAV_UAS_class"

rsgislib.vectorutils.createvectors.polygonise_raster_to_vec_lyr(
    out_vec_file=segs_vec_file_1,  # The output vector file name and path
    out_vec_lyr=segs_vec_lyr_1,  # The output vector layer name
    out_format="GPKG",  # The output vector format
    input_img=out_cls_img,  # The input segmentation image
    img_band=1,  # The band within the input image
    mask_img=out_cls_img,  # A mask image (usually the same as the input image)
    mask_band=1,  # The band within the mask image
)
# Out:
#  13%|█████▍                                    | 13/100 [00:00<00:01, 61.43it/s]
# Polygonising...
# 101it [00:02, 43.68it/s]
# Completed
